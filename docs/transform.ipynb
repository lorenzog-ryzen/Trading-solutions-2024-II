# %% [markdown]
# # From Months to Full Data

# %%
import pandas as pd

# %%
'''new_archive = open('prices_for_models.txt', 'w')
for index_month in range(5,10):
  archive_name = f'SPY_0{index_month}_2024_BidAndAsk.txt'
  with open(archive_name, 'r') as file:
    lines = file.readlines()
    for line in lines:
      date, hour, _,  _, _, bid_price, _, ask_price, _ = line.split(',')
      bid_price = float(bid_price)
      ask_price = float(ask_price)
      new_archive.write(f'{date},{hour},{bid_price},{ask_price}\n')
new_archive.close()'''

# %%
df = pd.read_csv('prices_for_models.txt', delimiter=',')
df
# Out:
#                date   time     bid    ask
# 0        2024.05.22  07:59  530.55  530.57
# 1        2024.05.22  07:59  530.55  530.58
# 2        2024.05.22  07:59  530.53  530.56
# 3        2024.05.22  07:59  530.53  530.57
# 4        2024.05.22  07:59  530.53  530.56
# ...             ...    ...     ...     ...
# 2191459  2024.09.27  19:19  570.65  570.68
# 2191460  2024.09.27  19:19  570.65  570.67
# 2191461  2024.09.27  19:19  570.65  570.66
# 2191462  2024.09.27  19:19  570.65  570.80
# 2191463  2024.09.27  23:36  570.65  570.80
#
# [2191464 rows x 4 columns]
