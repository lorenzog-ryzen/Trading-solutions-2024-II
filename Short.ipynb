# %%
import modules ;

# %%
with open('01-02-2023.txt','r') as reading :
    lines = reading.readlines()    
    for index, line in enumerate(lines): 
        current = modules.Archive_line(line.split(',')); 
        print(modules.time_detector_long(ET_time = modules.search_ET_time()[:5], current))
# Out:
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# long
# ...
