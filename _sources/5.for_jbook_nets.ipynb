# %%
import pandas as pd
from Net_Gens_copy import *

# %%
pop = Population(1,1000)
Gens, Nets= pop.initialize_population()
plot_network(Gens[0])
Gens[0].mutate()
plot_network(Gens[0])
# Out:
# DFS (0 -> 6): True
# DFS (0 -> 7): True
# Mutación válida, se realizó un cambio
# Caminos validados: [True, True]
# Función de mutación aplicada: <function Genotype.mutate.<locals>.add_random_connection at 0x000001A92B462EE0>
